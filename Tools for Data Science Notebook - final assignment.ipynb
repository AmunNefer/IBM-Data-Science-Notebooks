# %% [markdown]
# <h1>My Juypter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Henry Curtis Pelgrift</b> Researcher, Project Manager, Policy Analyst

# %% [markdown]
# <i>I have always loved computers, and I know most everything about their workings and building and overclocking them. The one thing I don't know is there their languages, so I'm trying to fix that by learning coding languages!

# %% [markdown]
# <h3>With luck, this will be a small Python function related to cat sizes as per the THIS CAT IS C H O N K Y Facebook Group.</h3>

# %%
#A function for accurately stating cat H E F T. 

def cat(size): #A function for producing statements
    if size == "kitten":
        print("an smol")
    elif size == "normal":
        print("S L O N K hamb")
    elif size == "kinda fat":
        print("L O R G E AND IN C H O R G E")
    elif size == "fat":
        print("C H O N K")
    elif size == "super fat":
        print("OH LAWD HE COMIN")


cat("super fat") #Change the wording in the parenthesis to match any of the terms above.
# Out:
# OH LAWD HE COMIN

# %% [markdown]
# <center>
#
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Juvenile_Ragdoll.jpg/1024px-Juvenile_Ragdoll.jpg" alt="A KITTEN!">
# <center>Not just any kitten, a kitten by Leijurv on Wikipedia shared under a CC-BY-SA 4.0 licence.</center>
# </center>
# <center><small><del>High-key want to steal this baby. Look at those eyes and that wittle coal nose!</del></small></center>
